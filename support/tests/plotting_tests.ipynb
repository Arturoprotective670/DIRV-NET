# %%
# fix python imports relative paths issues
# %cd ../../
# Out:
# /mnt/asgard2

# %%
# auto reload imports if they been modified

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from source.framework.tools.plotting_helper import *

# %%
image_rgba = np.random.uniform(-3, 3, size=(64, 64))  # Example empty RGBA image
image_rgba[0:10, 1:10] = 3

heat_map_drawer(
    image_rgba,
    color_map_name="bwr",
    color_map_min_val=-3,
    color_map_max_val=3,
)
plt.show()

annotated_heat_map_drawer(
    image_rgba,
    "3.12 + 2.35\n[2.14, 6.27]",
    color_map_name="bwr",
    color_map_min_val=-3,
    color_map_max_val=3,
    # box_text_color=(255, 255, 255, 20),
    # box_background_color=(54, 54, 54, 200),
    box_text_color=(255, 255, 255, 100),
    box_background_color=(79, 44, 14, 180),
)
